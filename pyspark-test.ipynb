# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("JupyterTest").getOrCreate()
spark

data = [("Alice", 29), ("Bob", 31), ("Cathy", 25)]
df = spark.createDataFrame(data, ["name", "age"])
df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/04 19:29:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +-----+---+
# | name|age|
# +-----+---+
# |Alice| 29|
# |  Bob| 31|
# |Cathy| 25|
# +-----+---+
# 25/11/04 19:29:53 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 39430)
# Traceback (most recent call last):
#   File "/usr/lib64/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib64/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib64/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib64/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/home/agileox/.local/lib/python3.11/site-packages/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/home/agileox/.local/lib/python3.11/site-packages/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/home/agileox/.local/lib/python3.11/site-packages/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/home/agileox/.local/lib/python3.11/site-packages/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
